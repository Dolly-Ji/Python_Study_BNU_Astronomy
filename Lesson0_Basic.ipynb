# %% [markdown]
# ## Lesson_0 Python的一些规则与碎碎念念

# %% [markdown]
# >- 运行方式：
#
# 1） 交互式:
#
# 命令行：终端启动python
#
# 增强命令行：终端启动ipython
#
# 2）独占式：
#
# 文本编辑器写脚本
#
# 3）综合式：
#
# Jupyter Notebook

# %% [markdown]
# python对大小写敏感
#
# 如果一行程序太长，可用“\”符号扩展到下一行
#
# 如果一行中有多条语句，语句间以分号（;）分隔
#
# “#”为注释内容

# %%
print('Hello,\
my friend!')
# Out:
# Hello,my friend!

# %% [markdown]
# >- 终端使用
#
# win + R 弹出小窗口后输入cmd ，进入终端
#
# D:表示改变路径到D盘下
#
# cd 表示进入到某一目录下
#
# cd ..返回上层目录
#
# dir 表示列出当前目录下的文件和文件夹（我记得好像有个练习，记得去找一下）
#
# del 删除文件
#
# python ....py 运行Python脚本
#
# 在>>>后输入python或者ipython进入python环境
#
# exit() 退出终端或python环境
#
# > 注意缩进！！！

# %% [markdown]
# # Lesson_1 数据和方法

# %% [markdown]
# ## 🧩 数据类型及其转换
#
# | 序号 | 数据类型 | 示例与特征 | 转换函数 |
# | ---- | ---------- | ----------- | -------- |
# | **1** | **布尔类型（bool）** | 取值：`True` / `False` | `bool()` |
# | **2** | **数字类型（number）** | 示例：`1234`, `3.1415926`, `3+4j`<br>包含：<br>• 整型（`int`）<br>• 浮点型（`float`）<br>• 复数型（`complex`） | 整型：`int()`、`round()`<br>浮点型：`float()` |
# | **3** | **字符串（str）** | 用引号括起，如：`"Hello"` 或 `'World'` | `str()` |
# | **4** | **列表（list）** | 用方括号 `[]` 表示；**有序、可变、可重复**<br>示例：`[1, 2, 3, 'a']` | `list()` |
# | **5** | **字典（dict）** | 用花括号 `{}` 表示；**无序、可变**<br>键唯一，值可重复<br>示例：`{'a': 1, 'b': 2}` | `dict()` |
# | **6** | **元组（tuple）** | 用圆括号 `()` 表示；**有序、不可变、可重复**<br>示例：`(1, 2, 3)` | `tuple()` |
# | **7** | **集合（set）** | 用花括号 `{}` 表示；**无序、可变、自动去重**<br>示例：`{1, 2, 2, 3}` → `{1, 2, 3}` | `set()` |

# %%
# set()表示集合，输出类似一个只储存值的字典
print(set('abca'))

print(set([5,9,20,4,5]))
# Out:
# {'a', 'b', 'c'}
# {9, 4, 20, 5}

# %%
s = [1,0]
print(bool(s))

a = [0,0]
print(bool(a))

l = []
print(bool(l))

print(tuple(s))
print(set(s))
# Out:
# True
# True
# False
# (1, 0)
# {0, 1}

# %% [markdown]
# 布尔类型
#
# 运算符 not,or and  ~~易考终端下的运行结果是什么 ~~
#
# 测试 in,is
#
# >- 经转换为布尔类型为`False`的情况
#
# | 类型      | 示例                    | 解释       |
# | ---------- | ----------------------- | ---------- |
# | `None`     | `bool(None)` → False    | 空值       |
# | `False`    | `bool(False)` → False   | 本身就是假 |
# | 数字       | `0`, `0.0`, `0j`        | 数值为零   |
# | 空字符串   | `''`                    | 没有内容的字符串 |
# | 空列表     | `[]`                    | 没有元素   |
# | 空元组     | `()`                    | 没有元素   |
# | 空字典     | `{}`                    | 没有键值对 |
# | 空集合     | `set()`                 | 没有元素   |

# %%
print(bool(0))
# Out:
# False

# %%
print(not 1==3)
print(1>2 or 2>1)
print((1>2) + (2>1))   # 加号前后要求都是数字，计算时会先把布尔值转为数字进行运算，最终输出结果再回到布尔值（False对应0，True对应1）
print((1>2) and (2>1))
print((1>2) * (2>1))
# Out:
# True
# True
# 1
# False
# 0
