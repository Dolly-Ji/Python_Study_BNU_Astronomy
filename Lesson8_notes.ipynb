# %% [markdown]
# ## Lesson 8

# %%
import urllib.request
url = 'http://172.16.85.56/python/ref/' # 很神奇之，最后一个/
response = urllib.request.urlopen(url)
html = response.read()
print(html)
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<html>\n <head>\n  <title>Index of /python/ref</title>\n </head>\n <body>\n<h1>Index of /python/ref</h1>\n  <table>\n   <tr><th valign="top"><img src="/icons/blank.gif" alt="[ICO]"></th><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr>\n   <tr><th colspan="5"><hr></th></tr>\n<tr><td valign="top"><img src="/icons/back.gif" alt="[PARENTDIR]"></td><td><a href="/python/">Parent Directory</a>       </td><td>&nbsp;</td><td align="right">  - </td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/layout.gif" alt="[   ]"></td><td><a href="%e2%80%9c%e7%ac%a8%e5%8a%9e%e6%b3%95%e2%80%9d%e5%ad%a6PYTHON(%e7%ac%ac3%e7%89%88).pdf">\xe2\x80\x9c\xe7\xac\xa8\xe5\x8a\x9e\xe6\xb3\x95\xe2\x80\x9d\xe5\xad\xa6PY..&gt;</a></td><td align="right">2018-10-14 12:00  </td><td align="right"> 36M</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/layout.gif" alt="[   ]"></td><td><a href="%e5%88%a9%e7%94%a8Python%e8%bf%9b%e8%a1%8c%e6%95%b0%e6%8d%ae%e5%88%86%e6%9e%90.pdf">\xe5\x88\xa9\xe7\x94\xa8Python\xe8\xbf\x9b\xe8\xa1\x8c\xe6\x95..&gt;</a></td><td align="right">2017-04-10 00:02  </td><td align="right"> 78M</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/image2.gif" alt="[IMG]"></td><td><a href="BNULogo.jpg">BNULogo.jpg</a>            </td><td align="right">2020-11-09 02:44  </td><td align="right">214K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/unknown.gif" alt="[   ]"></td><td><a href="Dive.Into.Python-5.4.cn.chm">Dive.Into.Python-5.4..&gt;</a></td><td align="right">2009-08-14 07:10  </td><td align="right">574K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/image2.gif" alt="[IMG]"></td><td><a href="IMG_1556_c.jpg">IMG_1556_c.jpg</a>         </td><td align="right">2020-02-26 11:41  </td><td align="right">395K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/layout.gif" alt="[   ]"></td><td><a href="Python%e5%ad%a6%e4%b9%a0%e6%89%8b%e5%86%8c(%e7%ac%ac4%e7%89%88).pdf">Python\xe5\xad\xa6\xe4\xb9\xa0\xe6\x89\x8b\xe5\x86\x8c(\xe7..&gt;</a></td><td align="right">2012-09-05 13:22  </td><td align="right"> 95M</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/layout.gif" alt="[   ]"></td><td><a href="Python%e7%bc%96%e7%a8%8b%e5%88%9d%e5%ad%a6%e8%80%85%e6%8c%87%e5%8d%97.pdf">Python\xe7\xbc\x96\xe7\xa8\x8b\xe5\x88\x9d\xe5\xad\xa6\xe8\x80..&gt;</a></td><td align="right">2020-07-09 07:49  </td><td align="right"> 88M</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/image2.gif" alt="[IMG]"></td><td><a href="opo0907h_0.jpg">opo0907h_0.jpg</a>         </td><td align="right">2020-11-08 21:08  </td><td align="right">144K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/image2.gif" alt="[IMG]"></td><td><a href="opo0907h_1.jpg">opo0907h_1.jpg</a>         </td><td align="right">2020-11-08 21:08  </td><td align="right">145K</td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/image2.gif" alt="[IMG]"></td><td><a href="opo0907h_2.jpg">opo0907h_2.jpg</a>         </td><td align="right">2020-11-08 21:08  </td><td align="right">152K</td><td>&nbsp;</td></tr>\n   <tr><th colspan="5"><hr></th></tr>\n</table>\n<address>Apache/2.4.58 (Win64) OpenSSL/3.1.3 PHP/8.2.12 Server at 172.16.85.56 Port 80</address>\n</body></html>\n'

# %%
from bs4 import BeautifulSoup as bs
soup = bs(html,'html.parser')
links = soup.findAll('a')
for a in links:
    print(url + a['href'])
    if "jpg" in a['href']:
        urllib.request.urlretrieve(url+a['href'],a['href'])
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# http://172.16.85.56/python/ref/?C=N;O=D
# http://172.16.85.56/python/ref/?C=M;O=A
# http://172.16.85.56/python/ref/?C=S;O=A
# http://172.16.85.56/python/ref/?C=D;O=A
# http://172.16.85.56/python/ref//python/
# http://172.16.85.56/python/ref/%e2%80%9c%e7%ac%a8%e5%8a%9e%e6%b3%95%e2%80%9d%e5%ad%a6PYTHON(%e7%ac%ac3%e7%89%88).pdf
# http://172.16.85.56/python/ref/%e5%88%a9%e7%94%a8Python%e8%bf%9b%e8%a1%8c%e6%95%b0%e6%8d%ae%e5%88%86%e6%9e%90.pdf
# http://172.16.85.56/python/ref/BNULogo.jpg
# http://172.16.85.56/python/ref/Dive.Into.Python-5.4.cn.chm
# http://172.16.85.56/python/ref/IMG_1556_c.jpg
# http://172.16.85.56/python/ref/Python%e5%ad%a6%e4%b9%a0%e6%89%8b%e5%86%8c(%e7%ac%ac4%e7%89%88).pdf
# http://172.16.85.56/python/ref/Python%e7%bc%96%e7%a8%8b%e5%88%9d%e5%ad%a6%e8%80%85%e6%8c%87%e5%8d%97.pdf
# http://172.16.85.56/python/ref/opo0907h_0.jpg
# http://172.16.85.56/python/ref/opo0907h_1.jpg
# http://172.16.85.56/python/ref/opo0907h_2.jpg

# %%
import os
print(f"当前工作目录: {os.getcwd()}")
# Out:
# 当前工作目录: d:\my study\Python Study\Lesson\Lesson_notes

# %%
import matplotlib.pyplot as plt

img = plt.imread('BNULogo.jpg')
img_s = img[::2,::2]
plt.imsave('logo_sml.png',img_s)

img_c = img[400:600:,400:600]
plt.imsave('logo_crop.png',img_c)

# %%
import numpy as np
comb = np.zeros([992,1280,3])
fname = 'opo0907h'
plt.figure()
for i in range(3):
    img = plt.imread(fname + '_' + str(i) + '.jpg')
    print(i,img.shape)
    comb[:,:,i] = img/255.
plt.imshow(comb)
plt.show()
# Out:
# 0 (992, 1280)
# 1 (992, 1280)
# 2 (992, 1280)

# %%
img = plt.imread('IMG_1556_c.jpg')
rows,cols = img.shape[:2]
B = np.sqrt(img[:,:,2]) * 12
B[B>255] = 255
G = img[:,:,1] ; R = img[:,:,0]
img_f = np.stack((R,G,B),axis =2)

img_f = img_f.astype('uint8')

plt.imsave('IMG_1556_r.png.png',img_f)

# %% [markdown]
# ## LaTeX高效编程
